# %% [markdown]
# <a href="https://colab.research.google.com/github/anweshbaidya-crypto/scam_prediction_model/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression

# Training data
# 0 = no suspicious words
# 1 = suspicious words present

X = np.array([[0], [0], [0], [1], [1], [1]])
y = np.array([0, 0, 0, 1, 1, 1])

# Create the model
model = LogisticRegression()

# Train the model
model.fit(X, y)

# Test a new email
prediction = model.predict([[1]])

# Display result
if prediction[0] == 1:
    print("The email is Spam")
else:
    print("The email is Not Spam")
# Out:
# The email is Spam

# %%
from sklearn.linear_model import LogisticRegression

X = [[1], [2], [3], [4], [5]]
y = [0, 0, 0, 1, 1]

model = LogisticRegression()
model.fit(X, y)

result = model.predict([[5]])

print("Prediction:", result)
# Out:
# Prediction: [1]
